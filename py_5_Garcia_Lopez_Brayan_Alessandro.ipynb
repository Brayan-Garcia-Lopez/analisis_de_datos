# %% [markdown]
# <a href="https://colab.research.google.com/github/Brayan-Garcia-Lopez/analisis_de_datos/blob/main/py_5_Garcia_Lopez_Brayan_Alessandro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

harvard = pd.read_csv('datasets/harvard_reviews.csv')

# %%
harvard.shape
# Out:
# (3184, 7)

# %%
harvard.head()
# Out:
#               published_date published_platform  rating    type  \
# 0  2023-12-28T08:02:14-05:00             Mobile       5  review
# 1  2023-12-12T00:38:26-05:00            Desktop       4  review
# 2  2023-12-10T08:21:35-05:00             Mobile       3  review
# 3  2023-11-07T21:20:21-05:00            Desktop       4  review
# 4  2023-10-02T17:40:42-04:00            Desktop       5  review
#
#    helpful_votes                                              title  \
# 0              0                 Best classes and good environment
# 1              0                                 Harvard University
# 2              0                                 Walk around campus
# 3              0                     Interesting Harvard University
# 4              0  Lovely university campus has many historic and...
#
#                                                 text
# 0  Good thanks for everything good work group 👍 h...
# 1  Harvard University was founded in 1636 and is ...
# ...

# %%
harvard.iloc[:, 1]
# Out:
# 0        Mobile
# 1       Desktop
# 2        Mobile
# 3       Desktop
# 4       Desktop
#          ...
# 3179    Desktop
# 3180    Desktop
# 3181    Desktop
# 3182    Desktop
# 3183    Desktop
# Name: published_platform, Length: 3184, dtype: object

# %%
harvard.iloc[:, 2]
# Out:
# 0       5
# 1       4
# 2       3
# 3       4
# 4       5
#        ..
# 3179    3
# 3180    3
# 3181    5
# 3182    5
# 3183    5
# Name: rating, Length: 3184, dtype: int64

# %%
harvard.iloc[:10, 2]
# Out:
# 0    5
# 1    4
# 2    3
# 3    4
# 4    5
# 5    4
# 6    5
# 7    5
# 8    4
# 9    4
# Name: rating, dtype: int64

# %% [markdown]
# En diciembre de 2023, Laura caminó por el campus de Harvard University. Había leído reseñas como “Best classes and good environment” y “Lovely university campus has many historic...”, pero estar ahí superaba cualquier comentario.
#
# Desde su móvil escribió: “Good thanks for everything, good work group”.
# A unos metros, otro visitante publicaba: “We did a walk around most of the Harvard Campus.”
#
# Distintos viajeros, la misma emoción: finalmente, estaban en Harvard.
